# %%
import pandasai as pai
from pandasai_litellm.litellm import LiteLLM

# %%
llm = LiteLLM(model="gemini/gemini-2.5-flash-lite", api_key="AIzaSyBOjDESyyRETNbDsmQ0GUfFGd_q5BdsTkA")

pai.config.set({"llm": llm})

# %%
df = pai.read_csv("plot.csv")
responce = df.chat("tell me dependencies of rates and rents for appartments")
print(responce)
# Out:
#    avg_price  avg_rent    Location
# 0  4125000.0   49500.0   Islamabad
# 1  2750000.0   33000.0  Rawalpindi
# 2  1375000.0   16500.0     Haripur

# %%
df = pai.read_csv("plot.csv")
responce = df.chat("tell me cheapest and the most expensive appartment price and also tell me their other details")
print(responce)
# Out:
#     Location  Floor  Size  Rooms Furnished Terrace For Family    Price  \
# 0    Haripur      2     5      1        No      No         No   500000
# 0  Islamabad      0    15      3       Yes     Yes        Yes  8100000
#
#      Rent Date_Listed  Rating  Area_SqFt
# 0    5000    1/1/2023     4.2      550.5
# 0  108000   3/18/2023     4.9     3710.0

# %%
df = pai.read_csv("plot.csv")
responce = df.chat("tell me me most expensive appartment in Haripur")
print(responce)
# Out:
#   Location  Floor  Size  Rooms Furnished Terrace For Family    Price   Rent  \
# 0  Haripur      0    15      3       Yes     Yes        Yes  2700000  36000
#
#   Date_Listed  Rating  Area_SqFt
# 0   1/18/2023     4.7     1710.0

# %%
df = pai.read_csv("plot.csv")
responce = df.chat("tell me me most cheapest appartment in Islamabad")
print(responce)
# Out:
#     Location  Floor  Size  Rooms Furnished Terrace For Family    Price   Rent  \
# 0  Islamabad      2     5      1        No      No         No  1500000  15000
#
#   Date_Listed  Rating  Area_SqFt
# 0    3/1/2023     4.6     1500.5
#     Location  Floor  Size  Rooms Furnished Terrace For Family    Price   Rent  \
# 0  Islamabad      2     5      1        No      No         No  1500000  15000
#
#   Date_Listed  Rating  Area_SqFt
# 0    3/1/2023     4.6     1500.5
